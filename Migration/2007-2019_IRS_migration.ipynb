# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy
import datetime

# %%
state_inflow = pd.read_csv("data/IRS_Inflow_Migration.csv", sep = ",")
print(state_inflow.head())
print(state_inflow.info())
print(state_inflow.Year.unique())
# Out:
#   Inflow_State  Outflow_State_Code Origin_State  \
# 0           AL                96.0           AL
# 1           AL                97.0           AL
# 2           AL                98.0           AL
# 3           AL                97.0           AL
# 4           AL                 1.0           AL
#
#                 Origin_Extended_Name  Num_Returns  Num_Exceptions  \
# 0  AL Total Migration-US and Foreign        47578           97703
# 1              AL Total Migration-US        46908           96089
# 2         AL Total Migration-Foreign          670            1614
# 3      AL Total Migration-Same State        59337          119622
# 4                    AL Non-migrants      1582765         3468405
#
#    Adj_Gross_Income  Year
# 0           2754842  2018
# 1           2714756  2018
# 2             40086  2018
# 3           2833824  2018
# 4         104423723  2018
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33910 entries, 0 to 33909
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Inflow_State          33910 non-null  object
#  1   Outflow_State_Code    28300 non-null  float64
#  2   Origin_State          33910 non-null  object
#  3   Origin_Extended_Name  33910 non-null  object
#  4   Num_Returns           33910 non-null  int64
#  5   Num_Exceptions        33910 non-null  int64
#  6   Adj_Gross_Income      33910 non-null  int64
#  7   Year                  33910 non-null  int64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 2.1+ MB
# None
# [2018 2017 2016 2015 2014 2013 2012 2011 2010 2009 2008 2007]

# %%
print('Plot of Adjusted Gross Income from 2007 to 2018')
print(state_inflow.groupby('Year')['Adj_Gross_Income'].mean().plot.bar())
print(state_inflow.plot(kind='scatter', x='Year', y='Adj_Gross_Income'))
# Out:
# Plot of Adjusted Gross Income from 2007 to 2018
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
#Sum of adjusted gross income for Origin State
Sum_Origin_Adj_Income=state_inflow.groupby('Origin_State')['Adj_Gross_Income'].sum()
Sum_Origin_Adjincome=Sum_Origin_Adj_Income.sort_values(ascending=False).head()
print('Top Adjusted Gross Income for Incoming Migration from 2007-2018')
print(Sum_Origin_Adjincome)
print(Sum_Origin_Adjincome.plot.bar())
# Out:
# Top Adjusted Gross Income for Incoming Migration from 2007-2018
# Origin_State
# CA    12772393921
# TX     7485714247
# NY     7416407721
# FL     5864109562
# IL     4448724134
# Name: Adj_Gross_Income, dtype: int64
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
state_outflow = pd.read_csv("data/IRS_Outflow_Migration.csv", sep = ",")
print(state_outflow.head())
print(state_outflow.info())
print(state_outflow.Year.unique())
# Out:
#   Outflow_State  Outflow_State_Code Origin_State  \
# 0            AL                96.0           AL
# 1            AL                97.0           AL
# 2            AL                98.0           AL
# 3            AL                97.0           AL
# 4            AL                 1.0           AL
#
#                 Origin_Extended_Name  Num_Returns  Num_Exceptions  \
# 0  AL Total Migration-US and Foreign        45226           89318
# 1              AL Total Migration-US        44600           87927
# 2         AL Total Migration-Foreign          626            1391
# 3      AL Total Migration-Same State        59337          119622
# 4                    AL Non-migrants      1582765         3468405
#
#    Adj_Gross_Income  Year
# 0           2474087  2018
# 1           2439333  2018
# 2             34755  2018
# 3           2833824  2018
# 4         104423723  2018
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33910 entries, 0 to 33909
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Outflow_State         33910 non-null  object
#  1   Outflow_State_Code    28300 non-null  float64
#  2   Origin_State          33910 non-null  object
#  3   Origin_Extended_Name  33910 non-null  object
#  4   Num_Returns           33910 non-null  int64
#  5   Num_Exceptions        33910 non-null  int64
#  6   Adj_Gross_Income      33910 non-null  int64
#  7   Year                  33910 non-null  int64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 2.1+ MB
# None
# [2018 2017 2016 2015 2014 2013 2012 2011 2010 2009 2008 2007]

# %%
print('Plot of Adjusted Gross Income from 2007 to 2018 for Outflow Migration')
print(state_outflow.groupby('Year')['Adj_Gross_Income'].mean().plot.bar())
print(state_outflow.plot(kind='scatter', x='Year', y='Adj_Gross_Income'))
# Out:
# Plot of Adjusted Gross Income from 2007 to 2018 for Outflow Migration
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
#Sum of adjusted gross income for Origin State for Outflow Migration
Sum_Origin_Adj_Income=state_outflow.groupby('Outflow_State')['Adj_Gross_Income'].sum()
Sum_Origin_Adjincome=Sum_Origin_Adj_Income.sort_values(ascending=False).head()
print('Top Adjusted Gross Income for Outflow Migration from 2007-2018')
print(Sum_Origin_Adjincome)
print(Sum_Origin_Adjincome.plot.bar())
# Out:
# Top Adjusted Gross Income for Outflow Migration from 2007-2018
# Outflow_State
# CA    12861566014
# NY     7556728508
# TX     7413515415
# FL     5650915999
# IL     4529516458
# Name: Adj_Gross_Income, dtype: int64
# AxesSubplot(0.125,0.125;0.775x0.755)
